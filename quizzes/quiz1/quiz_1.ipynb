# %% [markdown]
# # <span style="color:darkblue"> QTM 151 - Quiz 1 </span>

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size="5">
#
# Print your Emory ID below

# %%
# Write your answer here
print(2636522)
# Out:
# 2636522

# %% [markdown]
# <font size = "5" >
# This quiz is open book
#
# - You can use the lecture notes
# - You will get partial credit for attempting the questions
# - To get full credit, the code should your run as intended
# - You should <span style="color:red"> NOT </span> communicate with other students
#
# Print the following message: <br>
#
# "I will abide by Emory's code of conduct"
#
# **By printing the message, you acknowledge that you will abide by Emory's code of conduct.**

# %%
# Write your answer here:
print("I will abdie by Emory's code of conduct")
# Out:
# I will abdie by Emory's code of conduct

# %% [markdown]
# <font size = "5">
#
# Import the libraries "numpy", "matplotlib.pytplot", and "pandas"

# %%
# Write your answer here

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## <span style="color:darkblue"> Part I: Visualizing Random Variables </span>

# %% [markdown]
# <font size = "5">
#
# (a) Create two random variables ...
#
#
# - Call them "vec_x" and "vec_z"
# - Generate "vec_x" from a uniform distribution with (low = 10, high = 20, size = 1000)
# - Generate "vec_z" from a chi-square distribution with (df = 1, size = 1000)
# - Plot a histogram of each variable
#     - Label the axes and title
#     - Each graph should have a different title
#
# To get full points, plot the histograms on a grid (See Lecture 6)

# %%
# Write your own code:
fig, list_subfig =plt.subplots(1,2, figsize=(10,3))
vec_x=np.random.uniform(low=10,high=20,size=1000)
vec_z=np.random.chisquare(df=1,size=1000)
plt.tight_layout

list_subfig[0].hist(x=vec_x)
list_subfig[0].set_xlabel("variable")
list_subfig[0].set_ylabel("frequency")
list_subfig[0].set_title ("Uniform Random")

list_subfig[1].hist(x=vec_z)
list_subfig[1].set_xlabel ("variable")
list_subfig[1].set_ylabel ("frequency")
list_subfig[1].set_title ("Chisquare Random")
# Out:
# Text(0.5, 1.0, 'Chisquare Random')

# %% [markdown]
# <font size = "5">
#
# (b) Create a new variable "vec_y" by the formula
#
# $ y = e^x + 2x + 5$
#
# - Use element-by-element vector operations (no loops)
# - Produce a scatter plot of "vec_y" against "vec_x"
# - Label the axes and the title
# - Change the color to "red", "green" or "purple" (you choose)
#
# Hint: You can use the numpy "exp()" function with vector arrays

# %%
# Write your own code:
x=vec_x
vec_y = np.exp(x) + 2*x + 5
plt.scatter(x=vec_x,y=vec_y, color="green")
plt.xlabel("x-variable")
plt.ylabel("y-variable")
plt.title("scatter plot")
# Out:
# Text(0.5, 1.0, 'scatter plot')

# %% [markdown]
# ## <span style="color:darkblue"> Part II: Operations over multiple datasets </span>

# %% [markdown]
# <font size = "5">
#
# (c) Creates two lists with ...
#
# - The names of the datasets
# - The years of the datasets (type manually based on the dataset names)
#
# To answer this question, you need to browse the Quiz folder
#
# You will find three datasets on the distribution of ages worldwide

# %%
# Write your own code

pd.read_csv("data_quiz/wdi_ages1980.csv")
pd.read_csv("data_quiz/wdi_ages2000.csv")
pd.read_csv("data_quiz/wdi_ages2020.csv")

list_name = ["wdi_ages1980","wdi_ages2000.csv","wdi_ages2020.csv"]
list_age= ["year"]

# %% [markdown]
# <font size = "5">
#
# (d) Create a loop that ...
#
#
# - Goes over the list of years
# - If the year $\ge$ 2000, print the message
#
# $\qquad$ "This dataset contains information on or after 2000.
#
# - If the year $<$ 2000, print the message
#
# $\qquad$ "This dataset contains information before 2000"

# %%
# Write your own code
for list_age in list_name:
    if list_age >= 2000:
        print("This dataset contains information on or after 2000")
    if list_age < 2000:
        print("This dataset contains information before 2000")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\jonw1\OneDrive\Desktop\Emory University\QTM151\qtm151_fall_2023\quizzes\quiz1\quiz_1.ipynb Cell 18 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/jonw1/OneDrive/Desktop/Emory%20University/QTM151/qtm151_fall_2023/quizzes/quiz1/quiz_1.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> # Write your own code
#       <a href='vscode-notebook-cell:/c%3A/Users/jonw1/OneDrive/Desktop/Emory%20University/QTM151/qtm151_fall_2023/quizzes/quiz1/quiz_1.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> for list_age in list_name:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jonw1/OneDrive/Desktop/Emory%20University/QTM151/qtm151_fall_2023/quizzes/quiz1/quiz_1.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a>     if list_age >= 2000:
#       <a href='vscode-notebook-cell:/c%3A/Users/jonw1/OneDrive/Desktop/Emory%20University/QTM151/qtm151_fall_2023/quizzes/quiz1/quiz_1.ipynb#X23sZmlsZQ%3D%3D?line=3'>4</a>         print("This dataset contains information on or after 2000")
#       <a href='vscode-notebook-cell:/c%3A/Users/jonw1/OneDrive/Desktop/Emory%20University/QTM151/qtm151_fall_2023/quizzes/quiz1/quiz_1.ipynb#X23sZmlsZQ%3D%3D?line=4'>5</a>     if list_age < 2000:
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %% [markdown]
# <font size = "5">
#
# (e) Your goal is to convert all the ".csv" data files to ".xlsx" (Excel) files
#
# <font size = "4">
#
# - **Before answering** this question do use your terminal (in Mac) or Anaconda prompt (in windows) to install the following package: ```conda install openpyxl```
# - Create a list with the ".csv" dataset names (including their relative subfolder "data_quiz/)
# - Create a new list called "list_newnames", with each element ending in ".xlsx" (including the subfolder "data_excel/")
# - Start an index
#
# $\qquad$ index = 0
#
# - Initiate a for loop over the list of dataset names. Inside the loop:
#     - Read the ".csv" dataset and store it in an object called "dataset"
#     - Create a variable called "filename" from the "list_newnames", extracting the element "index"
#     - Store "dataset" as an excel file with name "filename".
#
#     $\qquad$ index = index + 1
#
# Note: Check that you did it correctly by trying to open your new excel files outside "VSCode"

# %%
# Write your own code:
all_list = ["data_quiz/wdi_ages1980.csv", "data_quiz/wdi_ages2000.csv","data_quiz/wdi_ages2020.csv"]
list_newnames = ["data_quiz/wdi_ages1980.xlsx","data_quiz/wdi_ages2000.xlsx","data_quiz/wdi_ages2020.xlsx"]
dataset = [""]
index = 0
for var in all_list:
    pd.read_csv(list_newnames)
    index = index + 1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\jonw1\OneDrive\Desktop\Emory University\QTM151\qtm151_fall_2023\quizzes\quiz1\quiz_1.ipynb Cell 20 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/jonw1/OneDrive/Desktop/Emory%20University/QTM151/qtm151_fall_2023/quizzes/quiz1/quiz_1.ipynb#X25sZmlsZQ%3D%3D?line=4'>5</a> index = 0
#       <a href='vscode-notebook-cell:/c%3A/Users/jonw1/OneDrive/Desktop/Emory%20University/QTM151/qtm151_fall_2023/quizzes/quiz1/quiz_1.ipynb#X25sZmlsZQ%3D%3D?line=5'>6</a> for var in all_list:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jonw1/OneDrive/Desktop/Emory%20University/QTM151/qtm151_fall_2023/quizzes/quiz1/quiz_1.ipynb#X25sZmlsZQ%3D%3D?line=6'>7</a>     pd.read_csv(list_newnames)
#
# File c:\Users\jonw1\anaconda3\envs\qtm151\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\jonw1\anaconda3\envs\qtm151\Lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File c:\Users\jonw1\anaconda3\envs\qtm151\Lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\jonw1\anaconda3\envs\qtm151\Lib\site-packages\pandas\io\parsers\readers.py:1676, in TextFileReader._make_engine(self, f, engine)
#    1674 elif engine != "python":
#    1675     msg = f"Invalid file path or buffer object type: {type(f)}"
# -> 1676     raise ValueError(msg)
#    1678 try:
#    1679     return mapping[engine](f, **self.options)
#
# ValueError: Invalid file path or buffer object type: <class 'list'>

# %% [markdown]
# <font size = "5">
#
# (f) Your goal is to open each dataset, create a new variable, then plot
#
#
# <font size = "3">
#
# - Create a list with the ".csv" dataset names (including their relative subfolder "data_quiz/)
# - Start an index
#
# $\qquad$ index = 0
#
# - Initiate a for loop over the list of dataset names. Inside the loop:
#     - Read the dataset and store it in an object called "dataset"
#     - Create two new variables as
#
#     $\qquad$ percent_ages0to14 = dataset["percent_ages0to14"] <br>
#     $\qquad$ percent_ages15to64 = dataset["percent_ages15to64"]
#
#     - Calculate the percent of the population between ages 0 and 64 by adding the two previous variables
#     - Plot a histogram and label the axes
#     - Use plt.show() to display the plot
#     - Write
#
#     $\qquad$ index = index + 1
#
#
# This should produce a histogram for each dataset

# %%
# Write your own code:
list_csv = ["data_quiz/wdi_ages1980.xlsx","data_quiz/wdi_ages2000.xlsx","data_quiz/wdi_ages2020.xlsx"]
index = 0
percent_ages0to14 = dataset["percent_ages0to14"]
percent_ages15to64=dataset["percent_ages15to64"]
dataset=[""]
for i in list_csv:
    dataset = np.append(list_csv)
    index = index +1

plt.show()
